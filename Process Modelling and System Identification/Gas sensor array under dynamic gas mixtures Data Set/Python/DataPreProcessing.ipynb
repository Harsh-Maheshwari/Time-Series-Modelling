# %%
import pandas as pd

# %%
df = pd.read_csv("ethylene_CO_updated.csv")

# %%
df_sample=df.iloc[:100000,:]

# %%
df_sample.to_csv("ethylene_CO_sample.csv")

# %%
df = pd.read_csv("ethylene_methane.csv")

# %%
df_sample=df.sample(n = 100000)

# %%
df_sample.to_csv("ethylene_methane_sample.csv")
